# %%
from cement.config.configuration import Configuartion

# %%
object = Configuartion()

object.get_training_pipeline_config()
# Out:
# TrainingPipelineConfig(artifact_dir='c:\\Users\\sayan\\Cement-Strength-Prediction\\cement\\artifact')

# %%
from cement.entity.config_entity import DataIngestionConfig,DataTransformationConfig,DataValidationConfig,   \
ModelTrainerConfig,ModelEvaluationConfig,ModelPusherConfig,TrainingPipelineConfig
from cement.util.util import read_yaml_file

from cement.logger import logging
import sys,os
from cement.constant import *
from cement.exception import CementException

# %%
object.get_data_ingestion_config()
# Out:
# DataIngestionConfig(dataset_download_url='https://drive.google.com/uc?export=download&id=1W42yoxCeY3vnz34hKdFdWa3cLJh0pKgC', zip_download_dir='c:\\Users\\sayan\\Cement-Strength-Prediction\\cement\\artifact\\data_ingestion\\2022-07-28-14-43-31\\zip_data', raw_data_dir='c:\\Users\\sayan\\Cement-Strength-Prediction\\cement\\artifact\\data_ingestion\\2022-07-28-14-43-31\\raw_data', ingested_train_dir='c:\\Users\\sayan\\Cement-Strength-Prediction\\cement\\artifact\\data_ingestion\\2022-07-28-14-43-31\\ingested_data\\train', ingested_test_dir='c:\\Users\\sayan\\Cement-Strength-Prediction\\cement\\artifact\\data_ingestion\\2022-07-28-14-43-31\\ingested_data\\test')

# %%
object.get_data_validation_config()
# Out:
# DataValidationConfig(schema_file_path='c:\\Users\\sayan\\Cement-Strength-Prediction\\config\\schema.yaml', report_file_path='c:\\Users\\sayan\\Cement-Strength-Prediction\\cement\\artifact\\data_validation\\2022-07-28-14-43-31\\report.json', report_page_file_path='c:\\Users\\sayan\\Cement-Strength-Prediction\\cement\\artifact\\data_validation\\2022-07-28-14-43-31\\report.html')

# %%
from cement.util.util import read_yaml_file
import pandas as pd

# %%
path = r"C:\Users\sayan\Cement-Strength-Prediction\config\schema.yaml"



schema_file_path = read_yaml_file(path)

schema_file_path["columns"]
# Out:
# {'cement': 'float',
#  'blast_furnace_slag': 'float',
#  'fly_ash': 'float',
#  'water': 'float',
#  'superplasticizer': 'float',
#  'coarse_aggregate': 'float',
#  'fine_aggregate': 'float',
#  'age': 'int',
#  'concrete_compressive_strength': 'float'}

# %%
Data_path = r"C:\Users\sayan\Cement-Strength-Prediction\cement\artifact\data_ingestion\2022-07-27-21-24-27\ingested_data\train\concrete_data.csv"

train_data = pd.read_csv(Data_path)

train_data.dtypes.index,train_data.dtypes.values
# Out:
# (Index(['cement', 'blast_furnace_slag', 'fly_ash', 'water', 'superplasticizer',
#         'coarse_aggregate', 'fine_aggregate ', 'age',
#         'concrete_compressive_strength'],
#        dtype='object'),
#  array([dtype('float64'), dtype('float64'), dtype('float64'),
#         dtype('float64'), dtype('float64'), dtype('float64'),
#         dtype('float64'), dtype('int64'), dtype('float64')], dtype=object))

# %%
data_type = list(map(lambda x:str(x).replace("dtype('","").replace("64","").replace("')","") ,train_data.dtypes.values))
data_type
# Out:
# ['float', 'float', 'float', 'float', 'float', 'float', 'float', 'int', 'float']

# %%
columns = train_data.columns
columns
# Out:
# Index(['cement', 'blast_furnace_slag', 'fly_ash', 'water', 'superplasticizer',
#        'coarse_aggregate', 'fine_aggregate ', 'age',
#        'concrete_compressive_strength'],
#       dtype='object')

# %%
schema = dict(zip(columns,data_type))
schema
# Out:
# {'cement': 'float',
#  'blast_furnace_slag': 'float',
#  'fly_ash': 'float',
#  'water': 'float',
#  'superplasticizer': 'float',
#  'coarse_aggregate': 'float',
#  'fine_aggregate ': 'float',
#  'age': 'int',
#  'concrete_compressive_strength': 'float'}

# %%
schema_file_path["columns"]["cement"]
# Out:
# 'float'

# %%
schema["cement"] == schema_file_path["columns"]["cement"]
# Out:
# True

# %%
a = schema_file_path["columns"]
a.keys()
# Out:
# dict_keys(['cement', 'blast_furnace_slag', 'fly_ash', 'water', 'superplasticizer', 'coarse_aggregate', 'fine_aggregate', 'age', 'concrete_compressive_strength'])

# %%
list(a.values())
# Out:
# ['float', 'float', 'float', 'float', 'float', 'float', 'float', 'int', 'float']

# %%
list(schema.values()) == list(a.values())
# Out:
# True

# %%
[i.replace(" ","") for i in list(schema.keys())]
# Out:
# ['cement',
#  'blast_furnace_slag',
#  'fly_ash',
#  'water',
#  'superplasticizer',
#  'coarse_aggregate',
#  'fine_aggregate',
#  'age',
#  'concrete_compressive_strength']

# %%
list(a.keys())
# Out:
# ['cement',
#  'blast_furnace_slag',
#  'fly_ash',
#  'water',
#  'superplasticizer',
#  'coarse_aggregate',
#  'fine_aggregate',
#  'age',
#  'concrete_compressive_strength']

# %%
len(list(a.keys()))
# Out:
# 9

# %%
len(list(schema.keys()))
# Out:
# 9

# %%
for i in list(schema.keys()):
    if i  in list(a.keys()):
        print(i,"yes")

    else:
        
        print(i,"No")
# Out:
# cement yes
# blast_furnace_slag yes
# fly_ash yes
# water yes
# superplasticizer yes
# coarse_aggregate yes
# fine_aggregate  No
# age yes
# concrete_compressive_strength yes

# %%
list(schema_file_path[DATASET_SCHEMA_COLUMNS_KEY].keys())
# Out:
# ['cement',
#  'blast_furnace_slag',
#  'fly_ash',
#  'water',
#  'superplasticizer',
#  'coarse_aggregate',
#  'fine_aggregate',
#  'age',
#  'concrete_compressive_strength']

# %%
len(list(train_data.columns))
# Out:
# 9

# %%
list(train_data.columns)
b = [i.replace(" ","") for i in list(train_data.columns)]

# %%
for i in b:
    if i  in list(a.keys()):
        print(i,"yes")

    else:
        
        print(i,"No")
# Out:
# cement yes
# blast_furnace_slag yes
# fly_ash yes
# water yes
# superplasticizer yes
# coarse_aggregate yes
# fine_aggregate yes
# age yes
# concrete_compressive_strength yes

# %%
if b==list(a.keys()) and len(b)==len(list(a.keys())) and :
    print("yes")
else:
    print("No")
# Out:
# yes

# %%
object.get_data_transformation_config()
# Out:
# DataTransformationConfig(transformed_train_dir='c:\\Users\\sayan\\Cement-Strength-Prediction\\cement\\artifact\\data_transformation\\2022-07-28-18-04-30\\transformed_data\\train', transformed_test_dir='c:\\Users\\sayan\\Cement-Strength-Prediction\\cement\\artifact\\data_transformation\\2022-07-28-18-04-30\\transformed_data\\test', preprocessed_object_file_path='c:\\Users\\sayan\\Cement-Strength-Prediction\\cement\\artifact\\data_transformation\\2022-07-28-18-04-30\\preprocessed\\preprocessed.pkl')

# %%
from cement.util.util import load_data
from cement.util.util import read_yaml_file
import pandas as pd

# %%
path = r"C:\Users\sayan\Cement-Strength-Prediction\config\schema.yaml"



schema_file_path = read_yaml_file(path)

schema_file_path["numerical_columns"]
# Out:
# ['cement',
#  'blast_furnace_slag',
#  'fly_ash',
#  'water',
#  'superplasticizer',
#  'coarse_aggregate',
#  'fine_aggregate',
#  'age',
#  'concrete_compressive_strength']

# %%
file_path = r"C:\Users\sayan\Cement-Strength-Prediction\cement\artifact\data_ingestion\2022-07-28-20-42-06\ingested_data\train\concrete_data.csv"
path = r"C:\Users\sayan\Cement-Strength-Prediction\config\schema.yaml"

load_data(file_path=file_path,schema_file_path = path)
# Out:
#      cement  blast_furnace_slag  fly_ash  water  superplasticizer  \
# 0     143.0               169.0    143.0  191.0               8.0
# 1     388.6                97.1      0.0  157.9              12.1
# 2     159.8               250.0      0.0  168.4              12.2
# 3     250.0               180.0     95.0  159.0               9.5
# 4     305.3               203.5      0.0  203.5               0.0
# ..      ...                 ...      ...    ...               ...
# 819   168.9                42.2    124.3  158.3              10.8
# 820   218.9                 0.0    124.1  158.5              11.3
# 821   475.0                 0.0      0.0  228.0               0.0
# 822   190.3                 0.0    125.2  161.9               9.9
# 823   296.0                 0.0      0.0  192.0               0.0
#
#      coarse_aggregate  fine_aggregate  age  concrete_compressive_strength
# 0               967.0           643.0   28                          29.72
# ...

# %%
from cement.config.configuration import Configuartion

object = Configuartion()

object.get_model_trainer_config()
# Out:
# ModelTrainerConfig(trained_model_file_path='c:\\Users\\sayan\\Cement-Strength-Prediction\\cement\\artifact\\model_trainer\\2022-07-28-23-57-03\\trained_model\\model.pkl', base_accuracy=0.6, model_config_file_path='config\\model.yaml')

# %%
from cement.config.configuration import Configuartion

object = Configuartion()

# %%
object.get_model_evaluation_config()
# Out:
# ModelEvaluationConfig(model_evaluation_file_path='c:\\Users\\sayan\\Cement-Strength-Prediction\\cement\\artifact\\model_evaluation\\model_evaluation.yaml', time_stamp='2022-07-29-03-32-25')

# %%
object.get_model_pusher_config()
# Out:
# ModelPusherConfig(export_dir_path='c:\\Users\\sayan\\Cement-Strength-Prediction\\saved_models\\20220729033258')

# %% [markdown]
# ## Checking the workablibilty of module model_factory.py

# %%
from cement.entity.model_factory import ModelFactory

# %%
model_config_path=r"C:\Users\sayan\Cement-Strength-Prediction\config\model.yaml"

# %%
model_factory = ModelFactory(model_config_path=model_config_path)

# %%
## The Model we will be using or (used)
model_factory.get_initialized_model_list()
# Out:
# {'fit_intercept': True, 'normalize': True, 'copy_X': False}
# {'n_estimators': 40, 'min_samples_leaf': 3, 'max_depth': 6}
# {'min_samples_leaf': 2, 'min_samples_split': 4, 'max_depth': 6}
# {'n_estimators': 50, 'learning_rate': 1.0, 'loss': 'linear'}
# {'min_samples_split': 3, 'min_samples_leaf': 5, 'max_depth': 4, 'splitter': 'best', 'max_features': 'auto'}
# [InitializedModelDetail(model_serial_number='module_0', model=LinearRegression(copy_X=False, normalize=True), param_grid_search={'fit_intercept': [True, False], 'normalize': [True, False], 'copy_X': [True, False]}, model_name='sklearn.linear_model.LinearRegression'),
#  InitializedModelDetail(model_serial_number='module_1', model=RandomForestRegressor(max_depth=6, min_samples_leaf=3, n_estimators=40), param_grid_search={'min_samples_leaf': [4, 6], 'n_estimators': [50, 120, 80], 'max_depth': [4, 6, 8, 10]}, model_name='sklearn.ensemble.RandomForestRegressor'),
# ...

# %%
## Getting the Data

Data_path = r"C:\Users\sayan\Cement-Strength-Prediction\cement\artifact\data_transformation\2022-07-28-23-09-35\transformed_data\train\concrete_data.npz"

from cement.util.util import load_numpy_array_data

Data = load_numpy_array_data(Data_path)

X,y=Data[:,:-1],Data[:,-1]

# %%
X ## training independent data
# Out:
# array([[-1.32507194,  1.1476422 ,  1.37488678, ..., -0.06766205,
#         -1.64980654, -0.27117401],
#        [ 1.04826839,  0.29247568, -0.85798013, ..., -1.52604219,
#          1.84022145,  0.16794213],
#        [-1.16272619,  2.11104259, -0.85798013, ...,  0.97693922,
#         -1.09179711, -0.27117401],
#        ...,
#        [ 1.88318942, -0.8624154 , -0.85798013, ..., -0.51190317,
#         -2.25472827,  3.524044  ],
#        [-0.86799133, -0.8624154 ,  1.0969495 , ...,  1.46941223,
#          0.32050993, -0.49073207],
#        [ 0.15343405, -0.8624154 , -0.85798013, ...,  1.43006516,
#         -0.1436749 ,  0.70115457]])

# %%
y ## training dependent data
# Out:
# array([29.72, 55.2 , 39.46, 67.87, 25.89, 43.7 , 19.77, 14.94, 78.8 ,
#        43.38, 74.36, 33.7 , 53.72, 48.59, 38.07, 33.4 , 33.02,  8.2 ,
#        36.94, 20.28, 40.87,  9.73,  7.84, 44.03, 40.15, 43.8 , 60.32,
#        48.85, 42.13, 51.04, 24.44, 42.13, 14.2 , 39.44, 56.06, 79.3 ,
#        65.2 , 13.09, 13.33, 17.24, 61.09, 41.05, 49.77, 68.1 , 38.  ,
#        23.14, 41.68, 32.88, 50.7 , 13.2 , 18.75, 31.27, 73.7 , 33.73,
#         6.81, 53.58, 23.79, 43.58, 37.42, 56.5 , 72.3 , 13.82, 33.54,
#        47.4 , 46.24, 14.54, 18.03, 44.3 , 27.77, 25.48, 13.22, 32.33,
#        44.52, 17.96, 41.1 , 22.53, 31.65, 42.35, 12.18, 40.27, 26.06,
#        59.  , 11.58, 71.3 , 50.94,  9.74, 23.7 , 41.93, 69.84, 20.73,
#        41.54, 56.34, 39.45, 45.94, 41.54, 29.23, 42.29, 47.82,  4.9 ,
#        36.3 , 39.66, 17.96, 23.22, 56.14, 32.72, 15.42, 39.38, 35.3 ,
#        56.1 , 32.72, 41.2 , 35.85, 66.78, 36.15, 12.46, 26.2 , 30.88,
# ...

# %%
best_model = model_factory.get_best_model(X=X,y=y)
# Out:
# {'fit_intercept': True, 'normalize': True, 'copy_X': False}
# {'n_estimators': 40, 'min_samples_leaf': 3, 'max_depth': 6}
# {'min_samples_leaf': 2, 'min_samples_split': 4, 'max_depth': 6}
# {'n_estimators': 50, 'learning_rate': 1.0, 'loss': 'linear'}
# {'min_samples_split': 3, 'min_samples_leaf': 5, 'max_depth': 4, 'splitter': 'best', 'max_features': 'auto'}
# {'cv': 5, 'verbose': 2}
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV] END ....copy_X=True, fit_intercept=True, normalize=True; total time=   0.0s
# [CV] END ....copy_X=True, fit_intercept=True, normalize=True; total time=   0.0s
# [CV] END ....copy_X=True, fit_intercept=True, normalize=True; total time=   0.0s
# [CV] END ....copy_X=True, fit_intercept=True, normalize=True; total time=   0.0s
# [CV] END ....copy_X=True, fit_intercept=True, normalize=True; total time=   0.0s
# [CV] END ...copy_X=True, fit_intercept=True, normalize=False; total time=   0.0s
# ...

# %%
## The best Model
best_model
# Out:
# GridSearchedBestModel(model_serial_number='module_2', model=GradientBoostingRegressor(max_depth=6, min_samples_leaf=2, min_samples_split=4), best_model=GradientBoostingRegressor(max_depth=4, min_samples_leaf=2), best_parameters={'max_depth': 4, 'min_samples_leaf': 2, 'min_samples_split': 2}, best_score=0.9095074594402768)

# %%
model_factory.grid_searched_best_model_list
# Out:
# [GridSearchedBestModel(model_serial_number='module_0', model=LinearRegression(copy_X=False, normalize=True), best_model=LinearRegression(normalize=True), best_parameters={'copy_X': True, 'fit_intercept': True, 'normalize': True}, best_score=0.6122885200909378),
#  GridSearchedBestModel(model_serial_number='module_1', model=RandomForestRegressor(max_depth=6, min_samples_leaf=3, n_estimators=40), best_model=RandomForestRegressor(max_depth=10, min_samples_leaf=4, n_estimators=80), best_parameters={'max_depth': 10, 'min_samples_leaf': 4, 'n_estimators': 80}, best_score=0.8663494701472677),
#  GridSearchedBestModel(model_serial_number='module_2', model=GradientBoostingRegressor(max_depth=6, min_samples_leaf=2, min_samples_split=4), best_model=GradientBoostingRegressor(max_depth=4, min_samples_leaf=2), best_parameters={'max_depth': 4, 'min_samples_leaf': 2, 'min_samples_split': 2}, best_score=0.9095074594402768),
# ...

# %%
best_model.best_model
# Out:
# GradientBoostingRegressor(max_depth=4, min_samples_leaf=2)
